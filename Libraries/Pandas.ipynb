# %%
import numpy as np
import pandas  as pd

def sep ():
    print('*' * 20)

# %% [markdown]
# # Creating Dataframe

# %%
df = pd.DataFrame([[1,2,3],[1,2,4],[4,5,6],[6,7,8]]
                  
                  , columns=['A' , 'b' ,'c']
                  , index=['A','b','c','d']
                  )
print(df)
sep()
print(df.head(1))
sep()
print(df.tail(2))
# Out:
#    A  b  c
# A  1  2  3
# b  1  2  4
# c  4  5  6
# d  6  7  8
# ********************
#    A  b  c
# A  1  2  3
# ********************
#    A  b  c
# c  4  5  6
# d  6  7  8

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4 entries, A to d
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   A       4 non-null      int64
#  1   b       4 non-null      int64
#  2   c       4 non-null      int64
# dtypes: int64(3)
# memory usage: 128.0+ bytes
# None

# %% [markdown]
# ### Get Describtion And Data Exploration

# %%
df.describe().T
# Out:
#    count  mean       std  min   25%  50%  75%  max
# A    4.0  3.00  2.449490  1.0  1.00  2.5  4.5  6.0
# b    4.0  4.00  2.449490  2.0  2.00  3.5  5.5  7.0
# c    4.0  5.25  2.217356  3.0  3.75  5.0  6.5  8.0

# %%
print(df.nunique()) #the num of unique values in each column
# Out:
# A    3
# b    3
# c    4
# dtype: int64

# %%
print(df)
print(df['A'].nunique())
# Out:
#    A  b  c
# A  1  2  3
# b  1  2  4
# c  4  5  6
# d  6  7  8
# 3

# %% [markdown]
# # Loading Dataset

# %%
car = pd.read_csv("/Users/khaledayman/Desktop/main/workspace/lessonsVs/Newfile.csv")
print(car.head())
# Out:
#    symboling  normalized-losses         make fuel-type aspiration  \
# 0          3                NaN  alfa-romero       gas        std
# 1          1                NaN  alfa-romero       gas        std
# 2          2              164.0         audi       gas        std
# 3          2              164.0         audi       gas        std
# 4          2                NaN         audi       gas        std
#
#   num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0          two  convertible          rwd           front        88.6  ...
# 1          two    hatchback          rwd           front        94.5  ...
# 2         four        sedan          fwd           front        99.8  ...
# 3         four        sedan          4wd           front        99.4  ...
# 4          two        sedan          fwd           front        99.8  ...
#
#    engine-size  fuel-system  bore  stroke compression-ratio horsepower  \
# ...

# %%
print(car.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          200 non-null    int64
#  1   normalized-losses  164 non-null    float64
#  2   make               200 non-null    object
#  3   fuel-type          200 non-null    object
#  4   aspiration         200 non-null    object
#  5   num-of-doors       198 non-null    object
#  6   body-style         200 non-null    object
#  7   drive-wheels       200 non-null    object
#  8   engine-location    200 non-null    object
#  9   wheel-base         200 non-null    float64
#  10  length             200 non-null    float64
#  11  width              200 non-null    float64
#  12  height             200 non-null    float64
#  13  curb-weight        200 non-null    int64
#  14  engine-type        200 non-null    object
#  15  num-of-cylinders   200 non-null    object
# ...

# %%
print(car.describe())
# Out:
#         symboling  normalized-losses  wheel-base      length       width  \
# count  200.000000         164.000000  200.000000  200.000000  200.000000
# mean     0.830000         122.000000   98.848000  174.228000   65.898000
# std      1.248557          35.442168    6.038261   12.347132    2.102904
# min     -2.000000          65.000000   86.600000  141.100000   60.300000
# 25%      0.000000          94.000000   94.500000  166.675000   64.175000
# 50%      1.000000         115.000000   97.000000  173.200000   65.500000
# 75%      2.000000         150.000000  102.400000  183.500000   66.675000
# max      3.000000         256.000000  120.900000  208.100000   72.000000
#
#            height  curb-weight  engine-size        bore      stroke  \
# count  200.000000   200.000000   200.000000  196.000000  196.000000
# mean    53.791500  2555.705000   126.860000    3.330000    3.259847
# std      2.428449   518.594552    41.650501    0.271303    0.317383
# ...

# %%
print(car.nunique())
# Out:
# symboling              6
# normalized-losses     51
# make                  22
# fuel-type              2
# aspiration             2
# num-of-doors           2
# body-style             5
# drive-wheels           3
# engine-location        2
# wheel-base            52
# length                73
# width                 43
# height                49
# curb-weight          169
# engine-type            6
# num-of-cylinders       7
# engine-size           43
# fuel-system            8
# bore                  38
# stroke                36
# compression-ratio     32
# horsepower            58
# peak-rpm              22
# city-mpg              29
# highway-mpg           30
# price                185
# dtype: int64

# %%
print(car['symboling'].unique())
print(car['symboling'].nunique())
# Out:
# [ 3  1  2  0 -1 -2]
# 6

# %%
coffee = pd . read_excel('/Users/khaledayman/Desktop/main/workspace/Google/DataSets/coffeeOrdersData.xlsx')
print(coffee)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pandas/compat/_optional.py:135, in import_optional_dependency(name, extra, errors, min_version)
#     134 try:
# --> 135     module = importlib.import_module(name)
#     136 except ImportError:
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/importlib/__init__.py:88, in import_module(name, package)
#      87         level += 1
# ---> 88 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1387, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1360, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1324, in _find_and_load_unlocked(name, import_)
#
# ModuleNotFoundError: No module named 'openpyxl'
#
# ...

# %%
print(car.tail())
# Out:
#      symboling  normalized-losses   make fuel-type aspiration num-of-doors  \
# 195         -1               95.0  volvo       gas        std         four
# 196         -1               95.0  volvo       gas      turbo         four
# 197         -1               95.0  volvo       gas        std         four
# 198         -1               95.0  volvo    diesel      turbo         four
# 199         -1               95.0  volvo       gas      turbo         four
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 195      sedan          rwd           front       109.1  ...          141
# 196      sedan          rwd           front       109.1  ...          141
# 197      sedan          rwd           front       109.1  ...          173
# 198      sedan          rwd           front       109.1  ...          145
# 199      sedan          rwd           front       109.1  ...          141
#
# ...

# %%
display(car)
# Out:
#      symboling  normalized-losses         make fuel-type aspiration  \
# 0            3                NaN  alfa-romero       gas        std
# 1            1                NaN  alfa-romero       gas        std
# 2            2              164.0         audi       gas        std
# 3            2              164.0         audi       gas        std
# 4            2                NaN         audi       gas        std
# ..         ...                ...          ...       ...        ...
# 195         -1               95.0        volvo       gas        std
# 196         -1               95.0        volvo       gas      turbo
# 197         -1               95.0        volvo       gas        std
# 198         -1               95.0        volvo    diesel      turbo
# 199         -1               95.0        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# ...

# %%
print(car.loc[4])
# Out:
# symboling                 2
# normalized-losses       NaN
# make                   audi
# fuel-type               gas
# aspiration              std
# num-of-doors            two
# body-style            sedan
# drive-wheels            fwd
# engine-location       front
# wheel-base             99.8
# length                177.3
# width                  66.3
# height                 53.1
# curb-weight            2507
# engine-type             ohc
# num-of-cylinders       five
# engine-size             136
# fuel-system            mpfi
# bore                   3.19
# stroke                  3.4
# compression-ratio       8.5
# horsepower            110.0
# peak-rpm             5500.0
# city-mpg                 19
# highway-mpg              25
# price                 15250
# Name: 4, dtype: object

# %%
print(car.loc[[4,1,6]])
# Out:
#    symboling  normalized-losses         make fuel-type aspiration  \
# 4          2                NaN         audi       gas        std
# 1          1                NaN  alfa-romero       gas        std
# 6          1                NaN         audi       gas        std
#
#   num-of-doors body-style drive-wheels engine-location  wheel-base  ...  \
# 4          two      sedan          fwd           front        99.8  ...
# 1          two  hatchback          rwd           front        94.5  ...
# 6         four      wagon          fwd           front       105.8  ...
#
#    engine-size  fuel-system  bore  stroke compression-ratio horsepower  \
# 4          136         mpfi  3.19    3.40               8.5      110.0
# 1          152         mpfi  2.68    3.47               9.0      154.0
# 6          136         mpfi  3.19    3.40               8.5      110.0
#
#    peak-rpm city-mpg  highway-mpg  price
# 4    5500.0       19           25  15250
# ...

# %%
print(car.loc[20:30])
# Out:
#     symboling  normalized-losses   make fuel-type aspiration num-of-doors  \
# 20          1              118.0  dodge       gas        std          two
# 21          1              118.0  dodge       gas      turbo          two
# 22          1              148.0  dodge       gas        std         four
# 23          1              148.0  dodge       gas        std         four
# 24          1              148.0  dodge       gas        std         four
# 25          1              148.0  dodge       gas      turbo          NaN
# 26         -1              110.0  dodge       gas        std         four
# 27          3              145.0  dodge       gas      turbo          two
# 28          2              137.0  honda       gas        std          two
# 29          2              137.0  honda       gas        std          two
# 30          1              101.0  honda       gas        std          two
#
#    body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# ...

# %%
print(car.loc[20:30 , ['symboling', 'normalized-losses',   'make', 'fuel-type', 'aspiration', 'num-of-doors']])
# Out:
#     symboling  normalized-losses   make fuel-type aspiration num-of-doors
# 20          1              118.0  dodge       gas        std          two
# 21          1              118.0  dodge       gas      turbo          two
# 22          1              148.0  dodge       gas        std         four
# 23          1              148.0  dodge       gas        std         four
# 24          1              148.0  dodge       gas        std         four
# 25          1              148.0  dodge       gas      turbo          NaN
# 26         -1              110.0  dodge       gas        std         four
# 27          3              145.0  dodge       gas      turbo          two
# 28          2              137.0  honda       gas        std          two
# 29          2              137.0  honda       gas        std          two
# 30          1              101.0  honda       gas        std          two

# %%
print(car.loc[20:30 , ['normalized-losses', 'fuel-type', 'num-of-doors']])
# Out:
#     normalized-losses fuel-type num-of-doors
# 20              118.0       gas          two
# 21              118.0       gas          two
# 22              148.0       gas         four
# 23              148.0       gas         four
# 24              148.0       gas         four
# 25              148.0       gas          NaN
# 26              110.0       gas         four
# 27              145.0       gas          two
# 28              137.0       gas          two
# 29              137.0       gas          two
# 30              101.0       gas          two

# %%
print(car.loc[: , ['symboling', 'aspiration', 'num-of-doors']])
print(car.loc)
# Out:
#      symboling aspiration num-of-doors
# 0            3        std          two
# 1            1        std          two
# 2            2        std         four
# 3            2        std         four
# 4            2        std          two
# ..         ...        ...          ...
# 195         -1        std         four
# 196         -1      turbo         four
# 197         -1        std         four
# 198         -1      turbo         four
# 199         -1      turbo         four
#
# [200 rows x 3 columns]
# ...

# %% [markdown]
#  loc      >> get the rows by (index / slicing / specification ) >> [ row ]
#  / [ [ multible rows ] ] /  [range 10:30] [range 10:30 , ["specefication column 1" ,"specifecation column 2"..... ]]
#
#
#  iloc      >> get the rows by (index / slicing / specification ) >> [ row ]
#  / [ [ multible rows ] ] /  [range 10:30] [range 10:30 , ["specefication column 1" ,"specifecation column 2"..... ]]

# %%
# print(car.iloc[: , [0,2,3]]) #..> Iloc by specify column by indexing
print(car.iloc[[1,2,3], [0,2,3]]) #..> Iloc by specify column by indexing
# Out:
#    symboling         make fuel-type
# 1          1  alfa-romero       gas
# 2          2         audi       gas
# 3          2         audi       gas

# %%
print(car.at[10,'num-of-doors'])
# Out:
# two

# %%
print(car.iat[10,2])
# Out:
# bmw

# %%
# print(car.symboling) #one word >> get the all column
# print(car.num-of-doors) #  multuble word >> error
print(car['num-of-doors']) 
print(car.loc[1:29, 'num-of-doors'])
# Out:
# 0       two
# 1       two
# 2      four
# 3      four
# 4       two
#        ...
# 195    four
# 196    four
# 197    four
# 198    four
# 199    four
# Name: num-of-doors, Length: 200, dtype: object
# 1      two
# 2     four
# 3     four
# 4      two
# 5     four
# 6     four
# 7     four
# 8      two
# 9     four
# 10     two
# 11    four
# 12    four
# 13    four
# 14     two
# 15    four
# 16     two
# 17     two
# 18    four
# 19     two
# 20     two
# 21     two
# 22    four
# 23    four
# 24    four
# 25     NaN
# 26    four
# 27     two
# 28     two
# 29     two
# Name: num-of-doors, dtype: object

# %%
print (car.sort_values("symboling" , ascending= True))
# Out:
#      symboling  normalized-losses           make fuel-type aspiration  \
# 193         -2              103.0          volvo       gas      turbo
# 191         -2              103.0          volvo       gas        std
# 189         -2              103.0          volvo       gas        std
# 199         -1               95.0          volvo       gas      turbo
# 66          -1               93.0  mercedes-benz    diesel      turbo
# ..         ...                ...            ...       ...        ...
# 127          3              150.0           saab       gas        std
# 129          3              150.0           saab       gas        std
# 131          3              150.0           saab       gas      turbo
# 100          3              194.0         nissan       gas        std
# 0            3                NaN    alfa-romero       gas        std
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# ...

# %%
car.sort_values(["symboling","normalized-losses" ] , ascending= [1,0])
# Out:
#      symboling  normalized-losses        make fuel-type aspiration  \
# 189         -2              103.0       volvo       gas        std
# 191         -2              103.0       volvo       gas        std
# 193         -2              103.0       volvo       gas      turbo
# 84          -1              137.0  mitsubishi       gas        std
# 26          -1              110.0       dodge       gas        std
# ..         ...                ...         ...       ...        ...
# 120          3                NaN    plymouth       gas      turbo
# 122          3                NaN     porsche       gas        std
# 123          3                NaN     porsche       gas        std
# 124          3                NaN     porsche       gas        std
# 184          3                NaN  volkswagen       gas        std
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 189         four        sedan          rwd           front       104.3  ...
# ...

# %%
# print(car.loc[car["num-of-doors"] == 'two'])
print(car.loc[(car["fuel-type"] == 'gas')|(car["fuel-type"] == 'diesel')])
print(car.loc[(car["fuel-type"] == 'gas')|(car["fuel-type"] == 'diesel'), ['symboling']])
# Out:
#      symboling  normalized-losses         make fuel-type aspiration  \
# 0            3                NaN  alfa-romero       gas        std
# 1            1                NaN  alfa-romero       gas        std
# 2            2              164.0         audi       gas        std
# 3            2              164.0         audi       gas        std
# 4            2                NaN         audi       gas        std
# ..         ...                ...          ...       ...        ...
# 195         -1               95.0        volvo       gas        std
# 196         -1               95.0        volvo       gas      turbo
# 197         -1               95.0        volvo       gas        std
# 198         -1               95.0        volvo    diesel      turbo
# 199         -1               95.0        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# ...

# %%
display(car.head())
# Out:
#    symboling  normalized-losses         make fuel-type aspiration  \
# 0          3                NaN  alfa-romero       gas        std
# 1          1                NaN  alfa-romero       gas        std
# 2          2              164.0         audi       gas        std
# 3          2              164.0         audi       gas        std
# 4          2                NaN         audi       gas        std
#
#   num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0          two  convertible          rwd           front        88.6  ...
# 1          two    hatchback          rwd           front        94.5  ...
# 2         four        sedan          fwd           front        99.8  ...
# 3         four        sedan          4wd           front        99.4  ...
# 4          two        sedan          fwd           front        99.8  ...
#
#    engine-size  fuel-system  bore  stroke compression-ratio horsepower  \
# ...

# %%
display(car.loc[car['engine-size' ] > 150 , ['make']])
# Out:
#               make
# 1      alfa-romero
# 10             bmw
# 11             bmw
# 12             bmw
# 13             bmw
# 14             bmw
# 15             bmw
# 27           dodge
# 43          jaguar
# 44          jaguar
# 45          jaguar
# 63   mercedes-benz
# 64   mercedes-benz
# 65   mercedes-benz
# 66   mercedes-benz
# 67   mercedes-benz
# 68   mercedes-benz
# 69   mercedes-benz
# 70   mercedes-benz
# 78      mitsubishi
# 79      mitsubishi
# 80      mitsubishi
# 97          nissan
# 98          nissan
# 99          nissan
# 100         nissan
# 101         nissan
# 102         nissan
# 104         peugot
# 106         peugot
# 108         peugot
# 110         peugot
# 112         peugot
# 120       plymouth
# 121        porsche
# 122        porsche
# 123        porsche
# 124        porsche
# 173         toyota
# 174         toyota
# 175         toyota
# 176         toyota
# 197          volvo

# %%
display(car[car['engine-location'] .str.contains('front')])
# Out:
#      symboling  normalized-losses         make fuel-type aspiration  \
# 0            3                NaN  alfa-romero       gas        std
# 1            1                NaN  alfa-romero       gas        std
# 2            2              164.0         audi       gas        std
# 3            2              164.0         audi       gas        std
# 4            2                NaN         audi       gas        std
# ..         ...                ...          ...       ...        ...
# 195         -1               95.0        volvo       gas        std
# 196         -1               95.0        volvo       gas      turbo
# 197         -1               95.0        volvo       gas        std
# 198         -1               95.0        volvo    diesel      turbo
# 199         -1               95.0        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# ...

# %%
display( car.loc[car['make'] .str.contains('peugot') , ['make', 'price']] )
# Out:
#        make  price
# 103  peugot  11900
# 104  peugot  13200
# 105  peugot  12440
# 106  peugot  13860
# 107  peugot  15580
# 108  peugot  16900
# 109  peugot  16695
# 110  peugot  17075
# 111  peugot  16630
# 112  peugot  17950
# 113  peugot  18150

# %%
display( car.loc[car['make'] .str.contains('peugot|toyota') , ['make', 'price']] )
# Out:
#        make  price
# 103  peugot  11900
# 104  peugot  13200
# 105  peugot  12440
# 106  peugot  13860
# 107  peugot  15580
# 108  peugot  16900
# 109  peugot  16695
# 110  peugot  17075
# 111  peugot  16630
# 112  peugot  17950
# 113  peugot  18150
# 145  toyota   5348
# 146  toyota   6338
# 147  toyota   6488
# 148  toyota   6918
# 149  toyota   7898
# 150  toyota   8778
# 151  toyota   6938
# 152  toyota   7198
# 153  toyota   7898
# 154  toyota   7788
# 155  toyota   7738
# 156  toyota   8358
# 157  toyota   9258
# 158  toyota   8058
# 159  toyota   8238
# 160  toyota   9298
# 161  toyota   9538
# 162  toyota   8449
# 163  toyota   9639
# 164  toyota   9989
# 165  toyota  11199
# 166  toyota  11549
# 167  toyota  17669
# 168  toyota   8948
# 169  toyota  10698
# 170  toyota   9988
# 171  toyota  10898
# 172  toyota  11248
# 173  toyota  16558
# 174  toyota  15998
# 175  toyota  15690
# 176  toyota  15750

# %%
display (car [car['make'].isin(['toyota'])])
# Out:
#      symboling  normalized-losses    make fuel-type aspiration num-of-doors  \
# 145          1               87.0  toyota       gas        std          two
# 146          1               87.0  toyota       gas        std          two
# 147          1               74.0  toyota       gas        std         four
# 148          0               77.0  toyota       gas        std         four
# 149          0               81.0  toyota       gas        std         four
# 150          0               91.0  toyota       gas        std         four
# 151          0               91.0  toyota       gas        std         four
# 152          0               91.0  toyota       gas        std         four
# 153          0               91.0  toyota    diesel        std         four
# 154          0               91.0  toyota    diesel        std         four
# 155          0               91.0  toyota       gas        std         four
# ...

# %%
display(car[
    car['make'].isin(
        ['toyota','peugot']
    ) 
    & (car['price'] > 11111)] 
    )
# Out:
#      symboling  normalized-losses    make fuel-type aspiration num-of-doors  \
# 103          0              161.0  peugot       gas        std         four
# 104          0              161.0  peugot    diesel      turbo         four
# 105          0                NaN  peugot       gas        std         four
# 106          0                NaN  peugot    diesel      turbo         four
# 107          0              161.0  peugot       gas        std         four
# 108          0              161.0  peugot    diesel      turbo         four
# 109          0                NaN  peugot       gas        std         four
# 110          0                NaN  peugot    diesel      turbo         four
# 111          0              161.0  peugot       gas        std         four
# 112          0              161.0  peugot    diesel      turbo         four
# 113          0              161.0  peugot       gas      turbo         four
# ...

# %%
print(car['price'].dtype)
# Out:
# int64

# %%
display(car[ car['make'].isin(["toyota","peugot"]) & (car['body-style'].str.contains('sedan'))])
# Out:
#      symboling  normalized-losses    make fuel-type aspiration num-of-doors  \
# 103          0              161.0  peugot       gas        std         four
# 104          0              161.0  peugot    diesel      turbo         four
# 107          0              161.0  peugot       gas        std         four
# 108          0              161.0  peugot    diesel      turbo         four
# 111          0              161.0  peugot       gas        std         four
# 112          0              161.0  peugot    diesel      turbo         four
# 113          0              161.0  peugot       gas      turbo         four
# 151          0               91.0  toyota       gas        std         four
# 153          0               91.0  toyota    diesel        std         four
# 155          0               91.0  toyota       gas        std         four
# 157          0               91.0  toyota       gas        std         four
# ...

# %%
display(car.query("make == 'toyota' and price > 5000"))
# Out:
#      symboling  normalized-losses    make fuel-type aspiration num-of-doors  \
# 145          1               87.0  toyota       gas        std          two
# 146          1               87.0  toyota       gas        std          two
# 147          1               74.0  toyota       gas        std         four
# 148          0               77.0  toyota       gas        std         four
# 149          0               81.0  toyota       gas        std         four
# 150          0               91.0  toyota       gas        std         four
# 151          0               91.0  toyota       gas        std         four
# 152          0               91.0  toyota       gas        std         four
# 153          0               91.0  toyota    diesel        std         four
# 154          0               91.0  toyota    diesel        std         four
# 155          0               91.0  toyota       gas        std         four
# ...

# %%
car['added_column'] = 5
car['added_column'] = car['price'] / 1000
display(car.head())
# Out:
#    symboling  normalized-losses         make fuel-type aspiration  \
# 0          3                NaN  alfa-romero       gas        std
# 1          1                NaN  alfa-romero       gas        std
# 2          2              164.0         audi       gas        std
# 3          2              164.0         audi       gas        std
# 4          2                NaN         audi       gas        std
#
#   num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0          two  convertible          rwd           front        88.6  ...
# 1          two    hatchback          rwd           front        94.5  ...
# 2         four        sedan          fwd           front        99.8  ...
# 3         four        sedan          4wd           front        99.4  ...
# 4          two        sedan          fwd           front        99.8  ...
#
#    fuel-system  bore  stroke  compression-ratio horsepower peak-rpm  city-mpg  \
# ...

# %%
car['added_column2'] = np.where(car['make'] == 'toyota' ,400 , 1)
display (car[car['make'].isin(['toyota' , 'volvo' , 'audi'])])
# Out:
#      symboling  normalized-losses    make fuel-type aspiration num-of-doors  \
# 2            2              164.0    audi       gas        std         four
# 3            2              164.0    audi       gas        std         four
# 4            2                NaN    audi       gas        std          two
# 5            1              158.0    audi       gas        std         four
# 6            1                NaN    audi       gas        std         four
# 7            1              158.0    audi       gas      turbo         four
# 145          1               87.0  toyota       gas        std          two
# 146          1               87.0  toyota       gas        std          two
# 147          1               74.0  toyota       gas        std         four
# 148          0               77.0  toyota       gas        std         four
# 149          0               81.0  toyota       gas        std         four
# ...

# %%
new_dataset = car

display (new_dataset)
# Out:
#      symboling  normalized-losses         make fuel-type aspiration  \
# 0            3                NaN  alfa-romero       gas        std
# 1            1                NaN  alfa-romero       gas        std
# 2            2              164.0         audi       gas        std
# 3            2              164.0         audi       gas        std
# 4            2                NaN         audi       gas        std
# ..         ...                ...          ...       ...        ...
# 195         -1               95.0        volvo       gas        std
# 196         -1               95.0        volvo       gas      turbo
# 197         -1               95.0        volvo       gas        std
# 198         -1               95.0        volvo    diesel      turbo
# 199         -1               95.0        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# ...

# %%
new_dataset.drop(columns=['added_column'])
# Out:
#      symboling  normalized-losses         make fuel-type aspiration  \
# 0            3                NaN  alfa-romero       gas        std
# 1            1                NaN  alfa-romero       gas        std
# 2            2              164.0         audi       gas        std
# 3            2              164.0         audi       gas        std
# 4            2                NaN         audi       gas        std
# ..         ...                ...          ...       ...        ...
# 195         -1               95.0        volvo       gas        std
# 196         -1               95.0        volvo       gas      turbo
# 197         -1               95.0        volvo       gas        std
# 198         -1               95.0        volvo    diesel      turbo
# 199         -1               95.0        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# ...

# %%
car['category'] = car['price'].apply(lambda x : "expensive" if x > 12000 else("avrage" if x > 9000 else "cheap"))
display(car['category'])
# Out:
# 0      expensive
# 1      expensive
# 2      expensive
# 3      expensive
# 4      expensive
#          ...
# 195    expensive
# 196    expensive
# 197    expensive
# 198    expensive
# 199    expensive
# Name: category, Length: 200, dtype: object

# %%
display (car[car['make'].isin(['toyota' , 'volvo' , 'audi'])].sort_values('price'))
# Out:
#      symboling  normalized-losses    make fuel-type aspiration num-of-doors  \
# 145          1               87.0  toyota       gas        std          two
# 146          1               87.0  toyota       gas        std          two
# 147          1               74.0  toyota       gas        std         four
# 148          0               77.0  toyota       gas        std         four
# 151          0               91.0  toyota       gas        std         four
# 152          0               91.0  toyota       gas        std         four
# 155          0               91.0  toyota       gas        std         four
# 154          0               91.0  toyota    diesel        std         four
# 153          0               91.0  toyota    diesel        std         four
# 149          0               81.0  toyota       gas        std         four
# 158          1              168.0  toyota       gas        std          two
# ...

# %%
def horse_power_measure (row) :
    if row['horsepower'] > 120 :
        return 'Extra speed'
    elif row['horsepower'] > 90 :
        return 'speed'
    elif row['horsepower'] > 65 :
        return 'little speed'
    else : return 'slow'

# %%
car ['speed_measure'] = car.apply(horse_power_measure ,axis=1 ) 
display (car[car['make'].isin(['alfa-romero', 'audi', 'bmw' ,'chevrolet','volvo'])])#.sort_values('horsepower'))
# Out:
#      symboling  normalized-losses         make fuel-type aspiration  \
# 0            3                NaN  alfa-romero       gas        std
# 1            1                NaN  alfa-romero       gas        std
# 2            2              164.0         audi       gas        std
# 3            2              164.0         audi       gas        std
# 4            2                NaN         audi       gas        std
# 5            1              158.0         audi       gas        std
# 6            1                NaN         audi       gas        std
# 7            1              158.0         audi       gas      turbo
# 8            2              192.0          bmw       gas        std
# 9            0              192.0          bmw       gas        std
# 10           0              188.0          bmw       gas        std
# 11           0              188.0          bmw       gas        std
# 12           1                NaN          bmw       gas        std
# ...

# %%
print(car['make'].unique())
# Out:
# ['alfa-romero' 'audi' 'bmw' 'chevrolet' 'dodge' 'honda' 'isuzu' 'jaguar'
#  'mazda' 'mercedes-benz' 'mercury' 'mitsubishi' 'nissan' 'peugot'
#  'plymouth' 'porsche' 'renault' 'saab' 'subaru' 'toyota' 'volkswagen'
#  'volvo']

# %%
car.loc[ [0,1] , 'aspiration' ] = np.nan

# %%
display (car[car['make'].isin(['alfa-romero', 'audi', 'bmw' ,'chevrolet','volvo'])])
# Out:
#      symboling  normalized-losses         make fuel-type aspiration  \
# 0            3                NaN  alfa-romero       gas        NaN
# 1            1                NaN  alfa-romero       gas        NaN
# 2            2              164.0         audi       gas        std
# 3            2              164.0         audi       gas        std
# 4            2                NaN         audi       gas        std
# 5            1              158.0         audi       gas        std
# 6            1                NaN         audi       gas        std
# 7            1              158.0         audi       gas      turbo
# 8            2              192.0          bmw       gas        std
# 9            0              192.0          bmw       gas        std
# 10           0              188.0          bmw       gas        std
# 11           0              188.0          bmw       gas        std
# 12           1                NaN          bmw       gas        std
# ...

# %%
print(car.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 30 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          200 non-null    int64
#  1   normalized-losses  164 non-null    float64
#  2   make               200 non-null    object
#  3   fuel-type          200 non-null    object
#  4   aspiration         198 non-null    object
#  5   num-of-doors       198 non-null    object
#  6   body-style         200 non-null    object
#  7   drive-wheels       200 non-null    object
#  8   engine-location    200 non-null    object
#  9   wheel-base         200 non-null    float64
#  10  length             200 non-null    float64
#  11  width              200 non-null    float64
#  12  height             200 non-null    float64
#  13  curb-weight        200 non-null    int64
#  14  engine-type        200 non-null    object
#  15  num-of-cylinders   200 non-null    object
# ...

# %%
print(car.isna().sum())
# Out:
# symboling             0
# normalized-losses    36
# make                  0
# fuel-type             0
# aspiration            2
# num-of-doors          2
# body-style            0
# drive-wheels          0
# engine-location       0
# wheel-base            0
# length                0
# width                 0
# height                0
# curb-weight           0
# engine-type           0
# num-of-cylinders      0
# engine-size           0
# fuel-system           0
# bore                  4
# stroke                4
# compression-ratio     0
# horsepower            2
# peak-rpm              2
# city-mpg              0
# highway-mpg           0
# price                 0
# added_column          0
# added_column2         0
# category              0
# speed_measure         0
# dtype: int64

# %%
print(car['normalized-losses'].isna().sum())
# Out:
# 36

# %%
car['normalized-losses'] . fillna(100)
car['normalized-losses'] . fillna(car['normalized-losses'].mean(), inplace=True)#..> to change on dataset iinplace true
# Out:
# /var/folders/qp/mnlhrt5x2rx27zstwr3s8_200000gp/T/ipykernel_1524/1425665535.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   car['normalized-losses'] . fillna(car['normalized-losses'].mean(), inplace=True)#..> to change on dataset iinplace true

# %%
print(car.isna().sum())
# Out:
# symboling            0
# normalized-losses    0
# make                 0
# fuel-type            0
# aspiration           2
# num-of-doors         2
# body-style           0
# drive-wheels         0
# engine-location      0
# wheel-base           0
# length               0
# width                0
# height               0
# curb-weight          0
# engine-type          0
# num-of-cylinders     0
# engine-size          0
# fuel-system          0
# bore                 4
# stroke               4
# compression-ratio    0
# horsepower           2
# peak-rpm             2
# city-mpg             0
# highway-mpg          0
# price                0
# added_column         0
# added_column2        0
# category             0
# speed_measure        0
# dtype: int64

# %%
display (car[car['make'].isin(['alfa-romero', 'audi', 'bmw' ,'chevrolet','volvo'])])
# Out:
#      symboling  normalized-losses         make fuel-type aspiration  \
# 0            3              122.0  alfa-romero       gas        NaN
# 1            1              122.0  alfa-romero       gas        NaN
# 2            2              164.0         audi       gas        std
# 3            2              164.0         audi       gas        std
# 4            2              122.0         audi       gas        std
# 5            1              158.0         audi       gas        std
# 6            1              122.0         audi       gas        std
# 7            1              158.0         audi       gas      turbo
# 8            2              192.0          bmw       gas        std
# 9            0              192.0          bmw       gas        std
# 10           0              188.0          bmw       gas        std
# 11           0              188.0          bmw       gas        std
# 12           1              122.0          bmw       gas        std
# ...

# %%
display(car.notna())
display(car["symboling"].notna())
display(car["symboling"].notna().sum())
# Out:
#      symboling  normalized-losses  make  fuel-type  aspiration  num-of-doors  \
# 0         True               True  True       True       False          True
# 1         True               True  True       True       False          True
# 2         True               True  True       True        True          True
# 3         True               True  True       True        True          True
# 4         True               True  True       True        True          True
# ..         ...                ...   ...        ...         ...           ...
# 195       True               True  True       True        True          True
# 196       True               True  True       True        True          True
# 197       True               True  True       True        True          True
# 198       True               True  True       True        True          True
# 199       True               True  True       True        True          True
#
# ...

# %%
print(car['price'].value_counts())
print(car['make'].value_counts())
# Out:
# price
# 16500    2
# 7775     2
# 7295     2
# 7957     2
# 6229     2
#         ..
# 16503    1
# 5389     1
# 6189     1
# 6669     1
# 22625    1
# Name: count, Length: 185, dtype: int64
# make
# toyota           32
# nissan           18
# mazda            17
# mitsubishi       13
# honda            13
# volkswagen       12
# subaru           12
# peugot           11
# volvo            11
# dodge             9
# mercedes-benz     8
# bmw               8
# plymouth          7
# audi              6
# saab              6
# porsche           4
# jaguar            3
# chevrolet         3
# isuzu             2
# renault           2
# alfa-romero       2
# mercury           1
# Name: count, dtype: int64

# %%
display(car.loc[car['make'].str.contains("volvo"),['make','price']])
display(car.loc[car['make'].isin(["volvo"]),['make','price']])
# Out:
#       make  price
# 189  volvo  12940
# 190  volvo  13415
# 191  volvo  15985
# 192  volvo  16515
# 193  volvo  18420
# 194  volvo  18950
# 195  volvo  16845
# 196  volvo  19045
# 197  volvo  21485
# 198  volvo  22470
# 199  volvo  22625
#       make  price
# 189  volvo  12940
# 190  volvo  13415
# 191  volvo  15985
# 192  volvo  16515
# 193  volvo  18420
# 194  volvo  18950
# 195  volvo  16845
# 196  volvo  19045
# 197  volvo  21485
# 198  volvo  22470
# 199  volvo  22625

# %%
print(car[car['make'] == "volvo"]['price'].value_counts())
# Out:
# price
# 12940    1
# 13415    1
# 15985    1
# 16515    1
# 18420    1
# 18950    1
# 16845    1
# 19045    1
# 21485    1
# 22470    1
# 22625    1
# Name: count, dtype: int64

# %%
print(car['make'].value_counts())
# Out:
# make
# toyota           32
# nissan           18
# mazda            17
# mitsubishi       13
# honda            13
# volkswagen       12
# subaru           12
# peugot           11
# volvo            11
# dodge             9
# mercedes-benz     8
# bmw               8
# plymouth          7
# audi              6
# saab              6
# porsche           4
# jaguar            3
# chevrolet         3
# isuzu             2
# renault           2
# alfa-romero       2
# mercury           1
# Name: count, dtype: int64

# %%
print(  car.groupby ( ['make'] )   ['price'].sum() )
# Out:
# make
# alfa-romero       33000
# audi             107155
# bmw              208950
# chevrolet         18021
# dodge             70879
# honda            106401
# isuzu             17833
# jaguar           103800
# mazda            181099
# mercedes-benz    269176
# mercury           16503
# mitsubishi       120117
# nissan           187482
# peugot           170380
# plymouth          55744
# porsche          125602
# renault           19190
# saab              91340
# subaru           102495
# toyota           316346
# volkswagen       120930
# volvo            198695
# Name: price, dtype: int64

# %%
car.groupby(['body-style']).agg({'horsepower': 'mean', 'price': 'sum'})
# Out:
#              horsepower    price
# body-style
# convertible  135.800000   117848
# hardtop      142.250000   177668
# hatchback     97.671642   677106
# sedan        103.808511  1359217
# wagon         97.750000   309299

# %%
car.groupby(['body-style','make']).agg({'horsepower': 'mean', 'price': 'sum'})
# Out:
#                            horsepower   price
# body-style  make
# convertible alfa-romero    111.000000   16500
#             mercedes-benz  155.000000   35056
#             porsche        207.000000   37028
#             toyota         116.000000   17669
#             volkswagen      90.000000   11595
# hardtop     mercedes-benz  153.500000   73576
#             nissan          69.000000    8249
#             porsche        207.000000   66556
#             toyota         116.000000   29287
# hatchback   alfa-romero    154.000000   16500
#             chevrolet       59.000000   11446
#             dodge           90.200000   39099
#             honda           74.000000   49381
#             isuzu           90.000000   11048
#             mazda           89.400000  100850
#             mercury        175.000000   16503
#             mitsubishi     105.000000   86381
#             nissan         137.200000   72045
#             plymouth        95.750000   32522
# ...

# %%
car.pivot_table(
    index=['body-style', 'make'],
    values=['horsepower', 'price'],
    aggfunc={
        'horsepower': 'mean',
        'price': 'sum'
    }
)
# Out:
#                            horsepower   price
# body-style  make
# convertible alfa-romero    111.000000   16500
#             mercedes-benz  155.000000   35056
#             porsche        207.000000   37028
#             toyota         116.000000   17669
#             volkswagen      90.000000   11595
# hardtop     mercedes-benz  153.500000   73576
#             nissan          69.000000    8249
#             porsche        207.000000   66556
#             toyota         116.000000   29287
# hatchback   alfa-romero    154.000000   16500
#             chevrolet       59.000000   11446
#             dodge           90.200000   39099
#             honda           74.000000   49381
#             isuzu           90.000000   11048
#             mazda           89.400000  100850
#             mercury        175.000000   16503
#             mitsubishi     105.000000   86381
#             nissan         137.200000   72045
#             plymouth        95.750000   32522
# ...

# %%
a = [1, 7, 2]

myvar = pd.Series(a , index= ['c','v','b'])

display(myvar)
print(myvar['c'])
# Out:
# c    1
# v    7
# b    2
# dtype: int64
# 1

# %%
calories = {"day1": 420, "day2": 380, "day3": 390}

myvar = pd.Series(calories )
myvar = pd.Series(calories , index= ["day2" ,"day1"])

print(myvar)
# Out:
# day2    380
# day1    420
# dtype: int64

# %%
data = {
  "calories": [420, 380, 390],
  "duration": [50, 40, 45]
}

#load data into a DataFrame object:
df = pd.DataFrame(data)

print(df)
# Out:
#    calories  duration
# 0       420        50
# 1       380        40
# 2       390        45

# %%
print(df.loc[0])
display(df.loc[0:1])
df.loc[[0,2]]
# Out:
# calories    420
# duration     50
# Name: 0, dtype: int64
#    calories  duration
# 0       420        50
# 1       380        40
#    calories  duration
# 0       420        50
# 2       390        45

# %%
print(car)
# Out:
#      symboling  normalized-losses         make fuel-type aspiration  \
# 0            3              122.0  alfa-romero       gas        NaN
# 1            1              122.0  alfa-romero       gas        NaN
# 2            2              164.0         audi       gas        std
# 3            2              164.0         audi       gas        std
# 4            2              122.0         audi       gas        std
# ..         ...                ...          ...       ...        ...
# 195         -1               95.0        volvo       gas        std
# 196         -1               95.0        volvo       gas      turbo
# 197         -1               95.0        volvo       gas        std
# 198         -1               95.0        volvo    diesel      turbo
# 199         -1               95.0        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# ...

# %%
pd.options.display.max_columns
# Out:
# 20

# %%
# pd.options.display.max_rows = 9999
pd.options.display.max_rows = 20
df=pd.read_csv("/Users/khaledayman/Desktop/main/workspace/lessonsVs/Newfile.csv")
print(df)
# Out:
#      symboling  normalized-losses         make fuel-type aspiration  \
# 0            3                NaN  alfa-romero       gas        std
# 1            1                NaN  alfa-romero       gas        std
# 2            2              164.0         audi       gas        std
# 3            2              164.0         audi       gas        std
# 4            2                NaN         audi       gas        std
# ..         ...                ...          ...       ...        ...
# 195         -1               95.0        volvo       gas        std
# 196         -1               95.0        volvo       gas      turbo
# 197         -1               95.0        volvo       gas        std
# 198         -1               95.0        volvo    diesel      turbo
# 199         -1               95.0        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# ...

# %%
car.duplicated()
car.drop_duplicates
# Out:
# <bound method DataFrame.drop_duplicates of      symboling  normalized-losses         make fuel-type aspiration  \
# 0            3              122.0  alfa-romero       gas        NaN
# 1            1              122.0  alfa-romero       gas        NaN
# 2            2              164.0         audi       gas        std
# 3            2              164.0         audi       gas        std
# 4            2              122.0         audi       gas        std
# ..         ...                ...          ...       ...        ...
# 195         -1               95.0        volvo       gas        std
# 196         -1               95.0        volvo       gas      turbo
# 197         -1               95.0        volvo       gas        std
# 198         -1               95.0        volvo    diesel      turbo
# 199         -1               95.0        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# ...
